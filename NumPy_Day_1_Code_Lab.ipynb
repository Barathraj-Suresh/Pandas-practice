# %% [markdown]
# # NumPy Day 1 — Code Lab
#
# **Level:** Beginner
# **Goal:** Learn NumPy arrays, properties, indexing, slicing, arithmetic, comparisons, and basic ML-style data handling.
#
# ### Topics
# 1. Import NumPy
# 2. Create 1D and 2D arrays
# 3. Array properties
# 4. Indexing
# 5. Slicing
# 6. Array arithmetic
# 7. Comparison operations
# 8. Mini ML dataset
# 9. Challenge

# %% [markdown]
# ## Part 1 — Import NumPy

# %%
# Task 1: Import NumPy and print its version

import numpy as np

print(np.__version__)
# Out:
# 2.5.3

# %%
# Task 2: Print this message

# Write your code here

arr = np.array([10,20,30,40,50])
print(arr)
# Out:
# [10 20 30 40 50]

# %% [markdown]
# ## Part 2 — Creating NumPy Arrays

# %%
# Task 3: Create a 1D NumPy array
# Values: 10, 20, 30, 40, 50

# Write your code here
arr = np.array([10,20,30,40,50])
print(arr)
# Out:
# [10 20 30 40 50]

# %%
# Task 4: Create this 2D NumPy array
# [[1, 2, 3],
#  [4, 5, 6]]

# Write your code here
arr_1 = np.array([[1,2,3],[4,5,6]])
print(arr_1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# Task 5: Create a NumPy array containing even numbers from 2 to 10

# Write your code here
arr =  np.array([2,4,6,8,10])
print(arr)
# Out:
# [ 2  4  6  8 10]

# %% [markdown]
# ## Part 3 — Array Properties

# %%
# Task 6

arr = np.array([10, 20, 30, 40, 50])

# Find:
# 1. Number of dimensions
# 2. Number of elements
# 3. Data type

# Write your code here

print("dimmension :",arr.ndim)
print("element :",arr.size)
print("Datatype:",arr.dtype)
# Out:
# dimmension : 1
# element : 5
# Datatype: int64

# %%
# Task 7

data = np.array([
    [10, 20, 30],
    [40, 50, 60]
])

# Find:
# 1. ndim
# 2. shape
# 3. size
# 4. dtype

# Write your code here
print("Dimension:",data.ndim)
print("Shape:",data.shape)
print("Size:",data.size)
print("Datatype:",data.dtype)
# Out:
# Dimension: 2
# Shape: (2, 3)
# Size: 6
# Datatype: int64

# %% [markdown]
# ## Part 4 — Indexing

# %%
# Task 8

arr = np.array([10, 20, 30, 40, 50])

# Print:
# 1. First element
# 2. Third element
# 3. Last element

# Write your code here
print(arr[0])
print(arr[2])
print(arr[-1])
# Out:
# 10
# 30
# 50

# %%
# Task 9

data = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# Print:
# 1. 10
# 2. 50
# 3. 90
# 4. 30

# Write your code here
print(data[0][0])
print(data[1,1])
print(data[2,2])
print(data[0,2])
# Out:
# 10
# 50
# 90
# 30

# %% [markdown]
# ## Part 5 — Slicing

# %%
# Task 10

arr = np.array([10, 20, 30, 40, 50])

# Print [20 30 40]

# Write your code here

# %%
# Task 11

data = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# Print:
# 1. First row
# 2. Second row
# 3. First column
# 4. Second column

# Write your code here
print(data[0,:])
print(data[1,:])
print(data[:,0])
print(data[:,1])
# Out:
# [10 20 30]
# [40 50 60]
# [10 40 70]
# [20 50 80]
# [20 50]

# %% [markdown]
# ## Part 6 — Array Arithmetic

# %%
# Task 12

arr = np.array([10, 20, 30, 40, 50])

# Perform:
# 1. Add 5
# 2. Subtract 5
# 3. Multiply by 2
# 4. Divide by 2

# Write your code here
print(arr+5)
print(arr-5)
print(arr*2)
print(arr/2)
# Out:
# [15 25 35 45 55]
# [ 5 15 25 35 45]
# [ 20  40  60  80 100]
# [ 5. 10. 15. 20. 25.]

# %%
# Task 13

marks = np.array([70, 80, 65, 90, 75])

# Add 5 bonus marks to every student

# Write your code here
print(marks+5)
# Out:
# [75 85 70 95 80]

# %% [markdown]
# ## Part 7 — Comparison Operations

# %%
# Task 14

marks = np.array([45, 67, 89, 32, 76, 91])

# Find which marks are:
# 1. Greater than 50
# 2. Less than 50
# 3. Equal to 76

# Write your code here
print(marks>50)
print(marks<50)
print(marks==76)
# Out:
# [False  True  True False  True  True]
# [ True False False  True False False]
# [False False False False  True False]

# %% [markdown]
# ## Part 8 — Mini ML Dataset
#
# Imagine this is a small student dataset:
#
# | Age | Marks |
# |---:|---:|
# | 20 | 80 |
# | 21 | 75 |
# | 22 | 90 |
# | 23 | 65 |
# | 24 | 85 |
#
# **Rows = students (samples), columns = features.**

# %%
students = np.array([
    [20, 80],
    [21, 75],
    [22, 90],
    [23, 65],
    [24, 85]
])

students
# Out:
# array([[20, 80],
#        [21, 75],
#        [22, 90],
#        [23, 65],
#        [24, 85]])

# %%
# Task 15: Find the shape of the dataset

# Write your code here
print(students.shape)
# Out:
# (5, 2)

# %%
# Task 16: Print the first student's complete data

# Write your code here
print('Age and Marks of a first student:',students[0])
# Out:
# Age and Marks of a first student: [20 80]

# %%
# Task 17: Print the marks of the first student

# Write your code here
print(students[0,1])
# Out:
# 80

# %%
# Task 18: Print all marks

# Hint: students[:, 1]

# Write your code here
print(students[:,1])
# Out:
# [80 75 90 65 85]

# %%
# Task 19: Print all ages

# Hint: students[:, 0]

# Write your code here
print(students[:,0])
# Out:
# [20 21 22 23 24]

# %%
# Task 20: Add 5 marks to every student's marks

# Write your code here
print(students[:,1]+5)
# Out:
# [85 80 95 70 90]

# %% [markdown]
# ## 🔥 Final Challenge
#
# Use the dataset below and solve all tasks **without looking at previous examples**.
#
# ```python
# students = np.array([
#     [20, 80],
#     [21, 75],
#     [22, 90],
#     [23, 65],
#     [24, 85]
# ])
# ```
#
# ### Tasks
# 1. Find the number of students.
# 2. Find the number of features.
# 3. Extract the marks.
# 4. Extract the ages.
# 5. Find students with marks greater than 80.
# 6. Add 10 marks to every student's marks.
# 7. Print the second student's complete data.

# %%
# Final Challenge

students = np.array([
    [20, 80],
    [21, 75],
    [22, 90],
    [23, 65],
    [24, 85]
])

# Solve the 7 tasks here.
print(students.shape[0])
print(students.shape[1])
print(students[:,1])
print(students[:,0])
print(students[:,1]>80)
print(students[:,1]+10)
print(students[1])
# Out:
# 5
# 2
# [80 75 90 65 85]
# [20 21 22 23 24]
# [False False  True False  True]
# [ 90  85 100  75  95]
# [21 75]

# %% [markdown]
# ## 🎯 Day 1 Recap
#
# By the end of this lab, you should be able to:
#
# - Import NumPy
# - Create 1D and 2D arrays
# - Understand `ndim`, `shape`, `size`, and `dtype`
# - Access array elements using indexing
# - Select data using slicing
# - Perform basic arithmetic on arrays
# - Perform comparison operations
# - Understand rows as samples and columns as features
# - Work with a simple ML-style numerical dataset
#
# **Next:** NumPy Day 2 — aggregation, reshaping, masking, random numbers, broadcasting, and matrix operations.
