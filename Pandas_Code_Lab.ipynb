# %% [markdown]
# # 🐼 Pandas Code Lab
# ## Beginner Hands-On Practical Session
#
# **Goal:** Learn Pandas by writing and running code in Jupyter Notebook.
#
# ### Topics
# - Series
# - DataFrame
# - Inspecting data
# - Selecting columns
# - Filtering rows
# - Adding/updating columns
# - Missing values
# - Basic statistics
# - GroupBy
# - Mini project

# %% [markdown]
# ## 1. Setup
#
# Run this cell first.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ## 2. Series
#
# A **Series** is a one-dimensional labelled data structure.
#
# ### Example

# %%
marks = pd.Series([80, 75, 90, 65, 88])
print(marks)
# Out:
# 0    80
# 1    75
# 2    90
# 3    65
# 4    88
# dtype: int64

# %% [markdown]
# ### 🧪 Practice 1
# Create a Series called `ages` containing:
#
# `20, 21, 19, 22, 20`
#
# Then print the Series and print the value at index `2`.

# %%
import pandas as pd

marks = pd.Series([85, 90, 78, 92, 88])

print(marks)
print("First mark:", marks[0])
print("Last mark:", marks[4])
print("Average:", marks.mean())
print("Maximum:", marks.max())
print("Minimum:", marks.min())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       3 marks = pd.Series([85, 90, 78, 92, 88])
#       5 print(marks)
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## 3. Create a DataFrame
#
# A **DataFrame** is a two-dimensional table with rows and columns.

# %%
data = {
    "Name": ["Arun", "Priya", "Rahul", "Divya", "Kiran"],
    "Department": ["AI", "DS", "AI", "CSE", "DS"],
    "Marks": [85, 92, 76, 88, 95],
    "Attendance": [90, 95, 75, 82, 98]
}

df = pd.DataFrame(data)
df
# Out:
#     Name Department  Marks  Attendance
# 0   Arun         AI     85          90
# 1  Priya         DS     92          95
# 2  Rahul         AI     76          75
# 3  Divya        CSE     88          82
# 4  Kiran         DS     95          98

# %% [markdown]
# ## 4. Inspect the DataFrame
#
# Try these commonly used commands.

# %%
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
#     Name Department  Marks  Attendance
# 0   Arun         AI     85          90
# 1  Priya         DS     92          95
# 2  Rahul         AI     76          75
# 3  Divya        CSE     88          82
# 4  Kiran         DS     95          98
#     Name Department  Marks  Attendance
# 0   Arun         AI     85          90
# 1  Priya         DS     92          95
# 2  Rahul         AI     76          75
# 3  Divya        CSE     88          82
# 4  Kiran         DS     95          98
# (5, 4)
# Index(['Name', 'Department', 'Marks', 'Attendance'], dtype='object')
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %% [markdown]
# ### 🧪 Practice 2
# 1. Display the first 3 rows.
# 2. Display the last 2 rows.
# 3. Find the number of rows and columns.
# 4. Display only the column names.

# %%
import pandas as pd

# Example DataFrame
data = {
    "Name": ["Arun", "Bala", "Charan", "Deepak", "Elango"],
    "Age": [20, 21, 19, 22, 20],
    "Mark": [85, 90, 78, 88, 92]
}

df = pd.DataFrame(data)

# 1. Display the first 3 rows
print(df.head(3))

# 2. Display the last 2 rows
print(df.tail(2))

# 3. Find the number of rows and columns
print(df.shape)

# 4. Display only the column names
print(df.columns)
# Out:
#      Name  Age  Mark
# 0    Arun   20    85
# 1    Bala   21    90
# 2  Charan   19    78
#      Name  Age  Mark
# 3  Deepak   22    88
# 4  Elango   20    92
# (5, 3)
# Index(['Name', 'Age', 'Mark'], dtype='object')

# %% [markdown]
# ## 5. Selecting Columns
#
# ### One column

# %%
df["Name"]
# Out:
# 0      Arun
# 1      Bala
# 2    Charan
# 3    Deepak
# 4    Elango
# Name: Name, dtype: object

# %% [markdown]
# ### Multiple columns

# %%
df[["Name", "Marks"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[["Name", "Marks"]]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Marks'] not in index"

# %% [markdown]
# ### 🧪 Practice 3
# Display:
# 1. `Name` and `Department`
# 2. `Name`, `Marks`, and `Attendance`

# %%
# 1. Display Name and Department
print(df[["Name", "Department"]])

# 2. Display Name, Marks, and Attendance
print(df[["Name", "Marks", "Attendance"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 1. Display Name and Department
# ----> 2 print(df[["Name", "Department"]])
#       4 # 2. Display Name, Marks, and Attendance
#       5 print(df[["Name", "Marks", "Attendance"]])
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Department'] not in index"

# %% [markdown]
# ## 6. Filtering Rows
#
# Find students who scored more than 80.

# %%
df[df["Marks"] > 80]

# %% [markdown]
# ### 🧪 Practice 4
# Write code to find:
# 1. Students with marks greater than 85.
# 2. Students with attendance greater than 90.
# 3. Students from the `AI` department.
# 4. Students with marks less than 80.

# %%
# 1. Students with marks greater than 85
print(df[df["Marks"] > 85])

# 2. Students with attendance greater than 90
print(df[df["Attendance"] > 90])

# 3. Students from the AI department
print(df[df["Department"] == "AI"])

# 4. Students with marks less than 80
print(df[df["Marks"] < 80])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 1. Students with marks greater than 85
# ----> 2 print(df[df["Marks"] > 85])
#       4 # 2. Students with attendance greater than 90
#       5 print(df[df["Attendance"] > 90])
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ## 7. Multiple Conditions
#
# Use `&` for AND and `|` for OR.
#
# Example: marks greater than 80 AND attendance greater than 85.

# %%
df[(df["Marks"] > 80) & (df["Attendance"] > 85)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[(df["Marks"] > 80) & (df["Attendance"] > 85)]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ### 🧪 Practice 5
# Find students who:
# 1. Have marks greater than 80 AND attendance greater than 90.
# 2. Are from AI OR DS department.

# %%
# 1
print(df[(df["Marks"] > 80) & (df["Attendance"] > 90)])

# 2
print(df[(df["Department"] == "AI") | (df["Department"] == "DS")])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 1
# ----> 2 print(df[(df["Marks"] > 80) & (df["Attendance"] > 90)])
#       4 # 2
#       5 print(df[(df["Department"] == "AI") | (df["Department"] == "DS")])
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ## 8. Add and Update Columns
#
# Create a `Pass` column.

# %%
df["Pass"] = df["Marks"] >= 40
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df["Pass"] = df["Marks"] >= 40
#       2 df
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ### 🧪 Practice 6
# 1. Create a `Bonus` column by adding 5 marks.
# 2. Create a `Final_Marks` column by adding `Marks + Bonus`.
# 3. Create a `High_Performer` column that is `True` when marks are 85 or above.

# %%
df["Bonus"] = 5
df["Final_Marks"] = df["Marks"] + df["Bonus"]
df["High_Performer"] = df["Marks"] >= 85

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 df["Bonus"] = 5
# ----> 2 df["Final_Marks"] = df["Marks"] + df["Bonus"]
#       3 df["High_Performer"] = df["Marks"] >= 85
#       5 df
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ## 9. Missing Values
#
# Create a DataFrame containing a missing mark.

# %%
data_missing = {
    "Name": ["Arun", "Priya", "Rahul", "Divya"],
    "Marks": [85, None, 76, 90]
}

df_missing = pd.DataFrame(data_missing)
df_missing
# Out:
#     Name  Marks
# 0   Arun   85.0
# 1  Priya    NaN
# 2  Rahul   76.0
# 3  Divya   90.0

# %% [markdown]
# Useful methods:
#
# - `isnull()` → find missing values
# - `isnull().sum()` → count missing values
# - `fillna()` → replace missing values

# %%
print(df_missing.isnull())
print(df_missing.isnull().sum())

# %% [markdown]
# ### 🧪 Practice 7
# Fill the missing mark using the **mean of the Marks column**.

# %%
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ## 10. Basic Statistics

# %%
print("Mean:", df["Marks"].mean())
print("Maximum:", df["Marks"].max())
print("Minimum:", df["Marks"].min())
print("Total:", df["Marks"].sum())
print(df["Marks"].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print("Mean:", df["Marks"].mean())
#       2 print("Maximum:", df["Marks"].max())
#       3 print("Minimum:", df["Marks"].min())
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Marks'

# %% [markdown]
# ### 🧪 Practice 8
# Find:
# 1. Average attendance
# 2. Highest attendance
# 3. Lowest attendance
# 4. Total marks

# %%
# Write your code here

# %% [markdown]
# ## 11. GroupBy
#
# Find the average marks for each department.

# %%
df.groupby("Department")["Marks"].mean()

# %% [markdown]
# ### 🧪 Practice 9
# 1. Find the average attendance for each department.
# 2. Find the maximum marks for each department.
# 3. Count the number of students in each department.

# %%
print(df.groupby("Department")["Attendance"].mean())
print(df.groupby("Department")["Marks"].max())
print(df["Department"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(df.groupby("Department")["Attendance"].mean())
#       2 print(df.groupby("Department")["Marks"].max())
#       3 print(df["Department"].value_counts())
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\moonf\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Department'

# %% [markdown]
# # 🚀 Mini Project: Student Performance Analyzer
#
# Use the following dataset.

# %%
project_data = {
    "Name": ["Arun", "Priya", "Rahul", "Divya", "Kiran", "Meena", "Vijay", "Anu"],
    "Department": ["AI", "DS", "AI", "CSE", "DS", "AI", "CSE", "DS"],
    "Marks": [85, 92, 67, 78, 95, 72, 88, 81],
    "Attendance": [90, 95, 75, 82, 98, 79, 91, 85]
}

students = pd.DataFrame(project_data)
students

# %% [markdown]
# ## 🎯 Mini Project Tasks
#
# Solve these independently.
#
# 1. Display the first 5 students.
# 2. Display only `Name` and `Marks`.
# 3. Find students who scored more than 80.
# 4. Find students with attendance greater than 85.
# 5. Find students with marks > 80 AND attendance > 85.
# 6. Find the average marks.
# 7. Find the highest-scoring student.
# 8. Find average marks for each department.
# 9. Add a `Performance` column: `Excellent` if marks >= 90, otherwise `Good`.
# 10. Find the number of students in each department.

# %%
# 🚀 Write your mini-project solution here

# %% [markdown]
# # ✅ Final Checklist
#
# Before finishing the lab, make sure you can write these without looking at the examples:
#
# - [ ] Create a Series
# - [ ] Create a DataFrame
# - [ ] Use `head()` and `tail()`
# - [ ] Use `shape`, `columns`, and `dtypes`
# - [ ] Select one or multiple columns
# - [ ] Filter rows
# - [ ] Use `&` and `|`
# - [ ] Add/update columns
# - [ ] Handle missing values
# - [ ] Calculate statistics
# - [ ] Use `groupby()`
# - [ ] Complete the mini project
